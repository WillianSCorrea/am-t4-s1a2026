# %% [markdown]
# <a href="https://colab.research.google.com/github/WillianSCorrea/am-t4-s1a2026/blob/main/Exercicio0428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

API_KEY =''
EMPRESA = []
lista_map = []

for sim in EMPRESA:

url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={}&apikey={}'
r = requests.get(url)
base = r.json()

# %%
base_alpha = pd.DataFrame.from_dict(base['Time Series (Daily)'], orient='index')
base_alpha = base_alpha.transpose()
base_alpha
