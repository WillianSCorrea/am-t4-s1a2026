# %% [markdown]
# <a href="https://colab.research.google.com/github/WillianSCorrea/am-t4-s1a2026/blob/main/NeuralizadorCredit0423.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Bibliotecas de Python

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Carregar

# %%
import pickle

# %%
with open('/content/drive/MyDrive/am-e4/credit.pkt', 'rb') as f:
 X_credit_trainamento,Y_credit_trainamento,X_credit_teste,Y_credit_teste = pickle.load(f)

# %%
X_credit_trainamento.shape ,Y_credit_trainamento.shape
# Out:
# ((1700, 3), (1700,))

# %%
X_credit_teste.shape ,Y_credit_teste.shape
# Out:
# ((300, 3), (300,))

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naive_credit = GaussianNB()
naive_credit.fit(X_credit_trainamento,Y_credit_trainamento)
# Out:
# GaussianNB()
